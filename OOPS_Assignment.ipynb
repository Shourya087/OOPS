# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)
# -- Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around objects rather than functions or logic. These objects represent real-world entities and combine data (attributes) and behavior (methods) into a single unit
#
# 2. What is a class in OOP
# -- class is a blueprint or a template to create objects. it defines attributes and methods
#
# 3. What is an object in OOP
# -- object is an instance of a class
#
# 4. What is the difference between abstraction and encapsulation
# -- abstraction is hiding complex implementation details and showing only features. encapsulation is bundling data and methods together
#
# 5. What are dunder methods in Python
# -- dunder methods are the double underscore methods. these are special methods which are built in class functions in python
#
# 6. Explain the concept of inheritance in OOP
# -- inheritance is concept where child class inherits the methods and attributes of the parent class
#
# 7. What is polymorphism in OOP
# -- polymorphism refers to an object taking several forms depending on the methods/data
#
# 8. How is encapsulation achieved in Python
# -- it means restricting direct access to attributes to protect internal state of the object. it is achieved using __ for private and _ for protected
#
# 9. What is a constructor in Python
# -- init function which is used to initialize objects
#
# 10. What are class and static methods in Python
# -- Defined with the @classmethod decorator.First parameter is always cls, which refers to the class itself (not the instance) Defined with the @staticmethod decorator. Do not take self (instance) or cls (class) as the first parameter. Behave like normal functions
#
# 11. What is method overloading in Python
# -- python doesnt support method overloading directly but defining multiple methods in same class with same name the last one overrides the previous ones
#
# 12. What is method overriding in OOP
# -- in inheritance the child class overrides the method which is also in parent class with same name
#
# 13. What is a property decorator in Python
# -- it is used to define methods that can be accessed like attributes. it turns method into read only attribute
#
# 14. Why is polymorphism important in OOP
# -- code reusability, flexiblility in code, simpler code
#
# 15. What is an abstract class in Python
# -- it is a class thta cant be instantiated directly and is meant to serve as a blueprint for other classes
#
# 16. What are the advantages of OOP
# -- encapsulation, inheritance, scalability, polymorphism, abstraction, security
#
# 17. What is the difference between a class variable and an instance variable
# -- Class varaibles - shared across all objects of the class, defined inside the class but outside any methods , changing a class variable affects all instances of the class, used for common properties that should be the same for every object
# Instance variable - unique to each object, defined inside the constructor (__init__) using self, changing an instance variable affects only that particular object, used for object-specific properties
#
# 18. What is multiple inheritance in Python
# -- inheritance where attributes and methods are inherited from more than 1 parent
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# -- str method is used to provide human readable string representation, repr method is used to provide developer oriented string representation
#
# 20. What is the significance of the ‘super()’ function in Python
# -- super function in Python is used to call method from parent class inside a child subclass
#
# 21. What is the significance of the __del__ method in Python
# -- del method is the destructor method . it is called qhen object is about to be destroyed
#
# 22. What is the difference between @staticmethod and @classmethod in Python
# -- staticmethod declares a method that does not depend on the class (cls) or instance (self). classmethod declares a method that operates on the class itself, not on instances.
#
# 23. How does polymorphism work in Python with inheritance
# -- parent class defines a method child classes override the method subclasses
#
# 24. What is method chaining in Python OOP
# -- method chaining is a programming technique where multiple methods are called sequentially on the same object in a single line of code
#
# 25. What is the purpose of the __call__ method in Python
# -- the call method is a special (dunder) method in python that allows an object of a class to be called like a function.

# %%
#Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
class Animal:
  def speak(self):
    print ("animal speaks")
class Dog(Animal):
  def speak(self):
    print('Bark!')

dog = Dog()
dog.speak()
# Out:
# Bark!

# %%
from abc import ABC, abstractmethod

#Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of Circle: {circle.area()}")
print(f"Area of Rectangle: {rectangle.area()}")
# Out:
# Area of Circle: 78.53975
# Area of Rectangle: 24

# %%
#Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
  def type(self):
    pass
class Car(Vehicle):
  pass
class ElectricCar(Car):
  def battery(self):
    print("battery atrribute")

veh = ElectricCar()
veh.battery()
# Out:
# battery atrribute

# %%
#Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
class Bird:
  def fly(self):
    print("Birds can fly.")

class Sparrow(Bird):
  def fly(self):
    print("Sparrows fly high in the sky.")

class Penguin(Bird):
  def fly(self):
    print("Penguins cannot fly, but they are great swimmers.")

def make_bird_fly(bird):
  bird.fly()

print("Demonstrating polymorphism:")
bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

make_bird_fly(bird)
make_bird_fly(sparrow)
make_bird_fly(penguin)
# Out:
# Demonstrating polymorphism:
# Birds can fly.
# Sparrows fly high in the sky.
# Penguins cannot fly, but they are great swimmers.

# %%
#Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
  def __init__(self, initial_balance=0):
    self.__balance = initial_balance # Private attribute
    print(f"Account created with initial balance: {self.__balance}")

  def deposit(self, amount):
    if amount > 0:
      self.__balance += amount
      print(f"Deposited: {amount}. New balance: {self.__balance}")
    else:
      print("Deposit amount must be positive.")

  def withdraw(self, amount):
    if amount > 0:
      if self.__balance >= amount:
        self.__balance -= amount
        print(f"Withdrew: {amount}. New balance: {self.__balance}")
      else:
        print("Insufficient funds.")
    else:
      print("Withdrawal amount must be positive.")

  def check_balance(self):
    print(f"Current balance: {self.__balance}")
    return self.__balance

# Example Usage:
my_account = BankAccount(100)
my_account.deposit(50)
my_account.withdraw(30)
my_account.check_balance()
my_account.withdraw(150) # Attempt to withdraw more than available
my_account.deposit(-10) # Attempt to deposit negative amount
my_account.check_balance()
# Out:
# Account created with initial balance: 100
# Deposited: 50. New balance: 150
# Withdrew: 30. New balance: 120
# Current balance: 120
# Insufficient funds.
# Deposit amount must be positive.
# Current balance: 120
# 120

# %%
#Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
class Instrument:
  def play(self):
    print("instrument is playing")

class Guitar(Instrument):
  def play(self):
    print("guitar is playing")

class Piano(Instrument):
  def play(self):
    print("paino is playing")

def instrument_playing(instrument):
  instrument.play()

print("Demonstrating polymorphism:")
ins = Instrument()
guitar = Guitar()
piano = Piano()

instrument_playing(ins)
instrument_playing(guitar)
instrument_playing(piano)
# Out:
# Demonstrating polymorphism:
# instrument is playing
# guitar is playing
# paino is playing

# %%
#Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers
class MathOperations:
  @classmethod
  def add_numbers(cls, x, y):
    return x + y

  @staticmethod
  def subtract_numbers(x, y):
    return x - y

print(MathOperations.add_numbers(10, 5))
print(MathOperations.subtract_numbers(10, 5))
# Out:
# 15
# 5

# %%
#Implement a class Person with a class method to count the total number of persons created.
class Person:
  total_persons = 0

  def __init__(self, name):
    self.name = name
    Person.total_persons += 1

  @classmethod
  def get_total_persons(cls):
    return cls.total_persons

# Example Usage:
print(f"Initial total persons: {Person.get_total_persons()}")

p1 = Person("Alice")
print(f"Total persons after p1: {Person.get_total_persons()}")

p2 = Person("Bob")
p3 = Person("Charlie")
print(f"Total persons after p2 and p3: {Person.get_total_persons()}")

p4 = Person("David")
print(f"Final total persons: {Person.get_total_persons()}")
# Out:
# Initial total persons: 0
# Total persons after p1: 1
# Total persons after p2 and p3: 3
# Final total persons: 4

# %%
#Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1, f2)
# Out:
# 3/4 7/2

# %%
#Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
  def __init__(self, x, y):
    self.x = x
    self.y = y


  def __add__(self, other):
    if isinstance(other, Vector):
      return Vector(self.x + other.x, self.y + other.y)
    else:
      raise TypeError("Can only add Vector objects to another Vector object")

  def __str__(self):
    return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(5, 1)

print(f"Vector 1: {v1}")
print(f"Vector 2: {v2}")

v3 = v1 + v2 # This calls the __add__ method
print(f"Sum of vectors (v1 + v2): {v3}")
# Out:
# Vector 1: (2, 3)
# Vector 2: (5, 1)
# Sum of vectors (v1 + v2): (7, 4)

# %%
#Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("shourya", 22)
p.greet()
# Out:
# Hello, my name is shourya and I am 22 years old.

# %%
#Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    if not self.grades:
      return
    return sum(self.grades) / len(self.grades)


student1 = Student("s1", [85, 90, 78, 92])
student2 = Student("s2", [70, 65, 80])

print(f"{student1.name}'s average grade: {student1.average_grade():.2f}")
print(f"{student2.name}'s average grade: {student2.average_grade():.2f}")
# Out:
# s1's average grade: 86.25
# s2's average grade: 71.67

# %%
#Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
  def __init__(self, length=0, width=0):
    self.length = length
    self.width = width

  def set_dimensions(self, l, b):
    self.length = l
    self.width = b
    print(f"Dimensions set to: Length={self.length}, Width={self.width}")

  def area(self):
    calculated_area = self.length * self.width
    print(f"Area of rectangle is {calculated_area}")
    return calculated_area

r = Rectangle()
r.set_dimensions(5, 10)
r.area()
# Out:
# Dimensions set to: Length=5, Width=10
# Area of rectangle is 50
# 50

# %%
#Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
  def __init__(self, work_hrs, rate):
    self.work_hrs = work_hrs
    self.rate = rate

  def calculate_salary(self):
    salary = self.work_hrs * self.rate
    return salary

class Manager(Employee):
  def __init__(self, work_hrs, rate, bonus):
    super().__init__(work_hrs, rate)
    self.bonus = bonus

  def calculate_salary(self):
    total_salary = salary + bonus
    print(total_salary)

e = Employee(20,1000)
e.calculate_salary()

m = Manager
m.calculate_salary(10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3134121690.py in <cell line: 0>()
#      22
#      23 m = Manager
# ---> 24 m.calculate_salary(10000)
#
# /tmp/ipython-input-3134121690.py in calculate_salary(self)
#      15
#      16   def calculate_salary(self):
# ---> 17     total_salary = salary + bonus
#      18     print(total_salary)
#      19
#
# NameError: name 'salary' is not defined

# %%
#Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    total_price = self.price * self.quantity
    print(f"Name of product is {self.name} and total price is {total_price}")
    return total_price

p = Product("Toothbrush", 25, 4)
p.total_price()
# Out:
# Name of product is Toothbrush and total price is 100
# 100

# %%
from abc import ABC, abstractmethod

#Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method
class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    print("cow moos")

class Sheep(Animal):
  def sound(self):
    print("sheep baas")

c = Cow()
c.sound()

s = Sheep()
s.sound()
# Out:
# cow moos
# sheep baas

# %%
#Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    print(f"title of book is {self.title} by author {self.author} published in year {self.year_published}")

b = Book("DS", 'SG', '2004')
b.get_book_info()
# Out:
# title of book is DS by author SG published in year 2004

# %%
#Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

my_mansion = Mansion("123 ktl", 5000000, 15)
print(my_mansion)
